# %%
import pandas as pd

keti2017 = pd.read_excel('data/KETI-2017-SL-Annotation-v2_1.xlsx')
keti2017.to_csv('data/keti2017.csv', index=False)

# %%
import pandas as pd

keti2018 = pd.read_excel('data/KETI-2018-SL-Annotation-v1.xlsx', sheet_name=1)
keti2018.to_csv('data/keti2018(학습용).csv', index=False)
keti2018
# Out:
#             번호 언어 제공자 ID    취득연도   방향 타입(단어/문장)                 파일명  한국어  \
# 0      10481.0        11  2018.0   정면        단어  KETI_SL_0000010481    0
# 1      10482.0        11  2018.0   정면        단어  KETI_SL_0000010482    1
# 2      10483.0        11  2018.0   정면        단어  KETI_SL_0000010483    2
# 3      10484.0        11  2018.0   정면        단어  KETI_SL_0000010484    3
# 4      10485.0        11  2018.0   정면        단어  KETI_SL_0000010485    4
# ...        ...       ...     ...  ...       ...                 ...  ...
# 33017      NaN       NaN     NaN  NaN       NaN                 NaN  NaN
# 33018      NaN       NaN     NaN  NaN       NaN                 NaN  NaN
# 33019      NaN       NaN     NaN  NaN       NaN                 NaN  NaN
# 33020      NaN       NaN     NaN  NaN       NaN                 NaN  NaN
# 33021      NaN       NaN     NaN  NaN       NaN                 NaN
#
#       Unnamed: 7
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# ...

# %%
keti2018.tail(15)
keti2018.drop(keti2018.tail(10).index, axis=0, inplace=True)
keti2018.drop('Unnamed: 7',axis=1, inplace=True)
keti2018.to_csv('data/keti2018(학습용).csv', index=False)

# %%
import pandas as pd

keti2018 = pd.read_excel('data/KETI-2018-SL-Annotation-v1.xlsx', sheet_name=2)
keti2018.to_csv('data/keti2018(응답용).csv', index=False)
keti2018
# Out:
#       번호  언어 제공자 ID  취득연도   방향 타입(단어/문장)                         파일명  \
# 0      1          1  2018   정면        문장  KETI_SL_RES_0000000001.MOV
# 1      2          1  2018   정면        문장  KETI_SL_RES_0000000002.MOV
# 2      3          1  2018   정면        문장  KETI_SL_RES_0000000003.MOV
# 3      4          1  2018   정면        문장  KETI_SL_RES_0000000004.MOV
# 4      5          1  2018   정면        문장  KETI_SL_RES_0000000005.MOV
# ..   ...        ...   ...  ...       ...                         ...
# 382  383          1  2018  우측면        문장  KETI_SL_RES_0000000383.MOV
# 383  384          1  2018  우측면        문장  KETI_SL_RES_0000000384.MOV
# 384  385          1  2018  우측면        문장  KETI_SL_RES_0000000385.MOV
# 385  386          1  2018  우측면        문장  KETI_SL_RES_0000000386.MOV
# 386  387          1  2018  우측면        문장  KETI_SL_RES_0000000387.MOV
#
#                                 한국어
# 0                           112입니다.
# 1                           119입니다.
# ...
