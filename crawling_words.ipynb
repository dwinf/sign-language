# %%
import urllib.request
import json
client_key = 'izGsqP2exeThwwEUVU3x'
client_secret = 'WrwbQ1l6ZI'
query = '진료'
encText = urllib.parse.quote_plus(query) # quote를 써도됨 공백이 없기 때문에  
num = 100
naver_url = 'https://openapi.naver.com/v1/search/blog.json?query=' + encText + '&display=' + str(num)

text = []
request = urllib.request.Request(naver_url)
request.add_header("X-Naver-Client-Id",client_key)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode == 200):
    response_body = response.read()
    dataList = json.loads(response_body)
    count = 1
    print('[' + query + '에 대한 네이버 블로그 글 ]')
        
    for data in dataList['items'] :
        print (str(count) + ' : ' + data['title'], end=" ")
        text.append(data['title'])
        #print ('[' + data['description'] + ']')
        text.append(data['description'])
        count += 1
else:
    print('오류 코드 : ' + rescode)
    
wfile = open("output/collect.txt","at", encoding="utf-8") 
wfile.writelines(text) 
wfile.close()
# Out:
# [진료에 대한 네이버 블로그 글 ]
# 1 : 치과<b>진료</b> / 내 생애 첫 임플란트 오스템! 2 : 노원역치과 기다리지말고 바로<b>진료</b> 플랜 YES! 3 : 외래<b>진료</b>를 받고 췌장암 조직검사를 위해 입원하다 4 : 안녕하세요 예젤의원(<b>진료</b>과목: 피부과) 대표원장 이상욱입니다. 5 : [소아 청소년<b>진료</b>] 뇌전증경험 엮은 한의학 책 &lt;뇌전증발달장애&gt; 6 : 38시간 수술해 살려 ‘강북삼성병원 뇌종양 다학제 <b>진료</b>팀’ 7 : 요추통증 어떤 <b>진료</b>로 개선할 수 있을까? 8 : 반려견스켈링 소록이의 <b>진료</b> 후기! 9 : 섬유근육통 치료 5개월차 외래 <b>진료</b> 10 : 비대면 <b>진료</b> 3주다이어트 한약 부작용 없이 후기 #가격 11 : 서울대병원<b>진료</b>-검사확인하기 12 : 소아<b>진료</b> / 김성철, 뇌전증발달장애 13 : 임신 28주 곽생로 임당재검/임당확정/내과 첫 <b>진료</b>/혈당측정기...  14 : 선릉역치과 합당한 <b>진료</b>를 받으려면 15 : 대구임플란트치과 섬세한 <b>진료</b>로 치아 관리 16 : 광주 치과 과잉<b>진료</b> 막는 디지털 진단 시스템 17 : 임신일기 - 6. 임신 8주차 증상 및 병원 <b>진료</b> 18 : 경산 권치과 <b>진료</b>시간 및 점심시간 19 : 대구치과추천 교정부터 일반<b>진료</b>까지 20 : 순천산부인과<b>진료</b> :: 임신초기에 피해야 하는 것들 ! 21 : 화성치과 개인별로 맞춤 <b>진료</b>하는 곳을 찾고있다면 22 : [주간 심평원] <b>진료</b>심사평가위원회 신임 위원장 취임부터...  23 : 경희의료원 입원 7. 세브란스전원을 위한 대리<b>진료</b>(대진) 24 : 과잉<b>진료</b> 부당이득반환청구소송 가능합니다 25 : &quot;<b>진료</b>는 전화로 약은 퀵으로?&quot;…꼼수 의사에 벌금 500만원 26 : 7개월 아이 심장중격결손 2차 병원 <b>진료</b> 27 : 성신여대역한의원 다이어트 한약 처방 비대면<b>진료</b>, 감량...  28 : 평택치과야간<b>진료</b> 팽성읍치과에서 미리 대비하자! 29 : 서울척추병원  <b>진료</b> 내몸에 맞추어 받아요! 30 : 5/1 근로자의날, 5/5 어린이날 <b>진료</b> 합니다 _ 분당
b> (혈액내과 / 안과 / 감염내과) 77 : 2021/04/20 첫 <b>진료</b> - 스마일라식 후 시력 1.0~1.2 78 : 병원선 첫 <b>진료</b>, &quot;첨도&quot; &quot;수락도&quot; 79 : <b>진료</b> 시 혀를 누를 때 사용하는 설압자 / 혀누르개 종류, 용도...  80 : 쏠 감기 <b>진료</b> 81 : MAY DAY5월 1일 근로자의 날 <b>진료</b> 안내 82 : 한담한의원 5월 <b>진료</b> 일정 안내 83 : 210325목 후두염,  <b>진료</b>확인서 84 : 바로세움병원 5월 가정의달 <b>진료</b>안내 85 : 청주 미앤유외과 - <b>진료</b>예약제 안내 (전화,인터넷) 86 : 화명동야간<b>진료</b> 퇴근이후에도 <b>진료</b>받기 87 : 2021년 5월 <b>진료</b> 안내 88 : [울산 소아과] 보람병원 소아청소년과 2021년 5월 <b>진료</b>일정...  89 : [국제성모병원앱] 쉽고 편하게 '<b>진료</b> 예약' 하기 90 : 강남역안과 5월 <b>진료</b>일정 안내 91 : 남양주어린이치과 5월 일요일 <b>진료</b> 안내 92 : '솔닥', 누적 원격<b>진료</b> 200건 돌파 93 : 연세숲 5월 <b>진료</b>일정 94 : 꽃마을한의원 5월 <b>진료</b>일정 안내 및 4월 임신 이야기♥ 95 : 익산시, 의료취약지역 한방순회<b>진료</b> 실시 96 : 연세맘스키즈치과 근로자의날 정상<b>진료</b> 안내 97 : 진도견 진돗개 왕순이 구토 췌장염 <b>진료</b> : 강아지 뼈 이물 삼킴...  98 : 일산치과<b>진료</b> 세균 방치하면 안되는 이유 99 : 일산치과추천 맞춤형 <b>진료</b> 시작 100 : 제주스케일링 꼼꼼한 <b>진료</b>로

# %%
import urllib.request
import json

client_key = 'izGsqP2exeThwwEUVU3x'
client_secret = 'WrwbQ1l6ZI'
query = '진료'
encText = urllib.parse.quote_plus(query)

num = 100
naver_url = 'https://openapi.naver.com/v1/search/news.json?query=' + encText + '&display=' + str(num)

text = []
request = urllib.request.Request(naver_url)
request.add_header("X-Naver-Client-Id",client_key)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)

rescode = response.getcode()

if(rescode == 200):
    response_body = response.read()
    dataList = json.loads(response_body)
    count = 1
    print('[' + query + '에 대한 네이버 뉴스 글 ]')
    for data in dataList['items'] :
        print (str(count) + ' : ' + data['title'], end=" ")
        text.append(data['title'])
        #print ('[' + data['description'] + ']')
        text.append(data['description'])
        count += 1
else:
    print('오류 코드 : ' + rescode)

wfile = open("output/collect.txt","at", encoding="utf-8") 
wfile.writelines(text) 
wfile.close()
# Out:
# [진료에 대한 네이버 뉴스 글 ]
# 1 : 충북도의 선제적 자가검사키트 도입 2 : 코로나 신규확진 564명…주말 검사건수 감소 영향 3 : 의정부성모병원, 만성폐쇄성 폐질환 적정성 1등급 4 : 휴일효과에 신규 확진자 500명대…특별방역점검주간 예정대로 종료 5 : 서산시, 코로나19 확진자 1명(#216 / 충남 #3145) 추가 발생 6 : 맹동농협, 고령농업인 및 마을경로당 구급상자 지원 7 : &quot;반려동물 보호자가 믿는 먹거리&quot; 청담우리동물병원 '메디코펫' 인기 8 : 건강보험 재정·의료비 부담 가중…“비급여 공급 통제해야” 9 : 여수시, 거
# %%
import urllib.request
import json
client_key = 'izGsqP2exeThwwEUVU3x'
client_secret = 'WrwbQ1l6ZI'
query = '병원'
encText = urllib.parse.quote_plus(query) # quote를 써도됨 공백이 없기 때문에  
num = 100
naver_url = 'https://openapi.naver.com/v1/search/blog.json?query=' + encText + '&display=' + str(num)

text = []
request = urllib.request.Request(naver_url)
request.add_header("X-Naver-Client-Id",client_key)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode == 200):
    response_body = response.read()
    dataList = json.loads(response_body)
    count = 1
    print('[' + query + '에 대한 네이버 블로그 글 ]')
        
    for data in dataList['items'] :
        print (str(count) + ' : ' + data['title'], end=" ")
        text.append(data['title'])
        #print ('[' + data['description'] + ']')
        text.append(data['description'])
        count += 1
else:
    print('오류 코드 : ' + rescode)
    
wfile = open("output/collect.txt","at", encoding="utf-8") 
wfile.writelines(text) 
wfile.close()
# Out:
# [병원에 대한 네이버 블로그 글 ]
# 1 : [토끼전문<b>병원</b>] 수원 레이동물<b>병원</b> 오픈 전 방문 후기 2 : 고양이동물<b>병원</b> 위급상황에 유용해요 3 : 안성동물<b>병원</b> 고양이 고난이도 수술후기! 4 : 수원토끼 레이동물<b>병원</b> 방문 5 : 구리동물<b>병원</b> 만족했던 후기! 6 : [<b>병원</b>일기]깽깽발 보고 놀란 가슴 강남예은동물<b>병원</b>에서...  7 : 편평사마귀 무제한 레이저시술 전문<b>병원</b> 8 : 모발이식<b>병원</b>추천 생착률이 중요한 이유! 9 : [마초] 결막염으로 <b>병원</b> 다녀온 날 10 : 동탄동물<b>병원</b> 아이도 좋아하는 곳 11 : 암요양<b>병원</b> 실비보상내용 12 : 송파구재활<b>병원</b> 골든타임 중요합니다 13 : 식도암요양<b>병원</b> 어떤 관리와 치료가 필요할까? 14 : 4월은 우리가족 <b>병원</b>신세 지는달 ...... ㅜ.ㅜ 15 : 광진구요양<b>병원</b> 재활까지 꼼꼼하게 16 : 유방암요양<b>병원</b> 몸과 마음의 안정을 위해 17 : 아기 후두염 13개월 아동<b>병원</b> 입원 준비물 18 : 암요양을 위한 암<b>병원</b> 선택기준 19 : 안산관절<b>병원</b>, 무지외반증교정 절개 없이 교정하세요! 20 : 내 몸에 맞는 교통사고 <b>병원</b> 입원 세심한 한방 케어 21 : 랑망이가 이용한 일본 동물 <b>병원</b> 정리 22 : 인천재활<b>병원</b> 후유증 재활관리 찾고있다면 23 : 비절개모발이식 <b>병원</b>추천 섬세한 디자인으로 24 : 깔끔한 진료 대전동물<b>병원</b> 25 : 송파재활<b>병원</b> 선택에 앞서서 살펴봐야 할 것 26 : 항암치료요양<b>병원</b> 최적화 된 관리로 27 : 배곧 서울대<b>병원</b> 기재부 예타 통과 소식 28 : <b>병원</b>회생 위기를 극복하려면 29 : 코로나19, <b>병원</b> 출입 30 : 대학<b>병원</b>에서 
, 건강검진 &amp; 분당 24시 폴 동물<b>병원</b> 75 : [5월]대학<b>병원</b> 조성 위해 한 걸음 더! 76 : 고양이사랑방)삼수니, 송이, 토끼 <b>병원</b> 가자 77 : 210429 목 ::: <b>병원</b>시르다 78 : 그런날 사이에 어떤날 (삼성서울<b>병원</b> 바이옵시 결과) 79 : 5월 5일, 개린이날 춘향이는 <b>병원</b>에 검사하러 총총총 80 : 원목 <b>병원</b>놀이세트 숲소리 81 : 핀란드에서 수요가 증가하고 있는 '<b>병원</b>특수학교' 82 : <b>병원</b>개원브랜딩 꼭 해야할지 고민이신가요? 83 : 무지외반증을 치료할 수 있는 <b>병원</b> 84 : [<b>병원</b>동업/공동개원] 함께 성장하는 방법 85 : <b>병원</b>홈페이지제작 딱 보고 업체 찾았죠!! 86 : 노화의 원인:   텔로미어 검사 <b>병원</b> , 비타민 87 : 해운대백<b>병원</b>에서 코로나 검사하다 (D+1319) 88 : 계족로는 공사중 - 법1동 유원아파트 ~ 근로복지공단 대전<b>병원</b> 앞 89 : 우리 오뎅이 염증이 재발해서 <b>병원</b> 다녀왔어요 90 : [앱테크] 모두닥 <b>병원</b>리뷰 어플 91 : 내 돈 주고 보낸 인형<b>병원</b> &quot;토이테일즈&quot; 후기/가격 92 : 산부인과  두군데 다니기 ,차<b>병원</b>+동네<b>병원</b> 93 : 우리 송이 <b>병원</b>가자 아무걱정 말고 94 : 미국간호사 취업 미군부대 군<b>병원</b> 미국간호장교 95 : 【산본제일<b>병원</b>분만소식】 4월의 탄생 96 : 배우 최우식, 서울대<b>병원</b> 후원회 홍보대사 위촉 97 : [분당서울대<b>병원</b> 가정의달 이벤트]- ♥감사합니데이♥ - 감사한...  98 : [JS노송<b>병원</b>] 5월 월례조회 99 : 병무용 진단서 받을 수 있는 병무청 지정<b>병원</b> 찾는 법! 100 : 고양이도 동물<b>병원</b> 가는것은 싫어해

# %%
import urllib.request
import json

client_key = 'izGsqP2exeThwwEUVU3x'
client_secret = 'WrwbQ1l6ZI'
query = '병원'
encText = urllib.parse.quote_plus(query)

num = 100
naver_url = 'https://openapi.naver.com/v1/search/news.json?query=' + encText + '&display=' + str(num)

text = []
request = urllib.request.Request(naver_url)
request.add_header("X-Naver-Client-Id",client_key)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)

rescode = response.getcode()

if(rescode == 200):
    response_body = response.read()
    dataList = json.loads(response_body)
    count = 1
    print('[' + query + '에 대한 네이버 뉴스 글 ]')
    for data in dataList['items'] :
        print (str(count) + ' : ' + data['title'], end=" ")
        text.append(data['title'])
        #print ('[' + data['description'] + ']')
        text.append(data['description'])
        count += 1
else:
    print('오류 코드 : ' + rescode)

wfile = open("output/collect.txt","at", encoding="utf-8") 
wfile.writelines(text) 
wfile.close()
# Out:
# [병원에 대한 네이버 뉴스 글 ]
총리 별세 88 : 인도 코로나 경증 교민 환자, 특별기로 한국 이송 추진 89 : 홍남기 총리대행 &quot;특별방역주간 종료...요양시설 접촉면회방안 이달 마련 90 : 여수시, 16일 24시까지 사회적거리두기 2단계 연장 91 : 인도 코로나 경증 교민 환자, 특별기로 한국 이송 추진 92 : 5월 9일 부음 93 : 김부겸, 이한동 빈소 조문…&quot;IMF 국난극복 큰 역할&quot; 94 : 홍남기 “특별방역 종료…이달 접촉면회방안 마련” 95 : 안동시보건소 공무원, 뇌출혈로 보름째 사경 96 : 홍남기 “특별방역주간 종료…스마트 방역으로 전환”(종합) 97 : 김부겸, 이한동 전 총리 조문…&quot;IMF 국난 때 민심 수습 큰 역할&quot; 98 : 홍남기 &quot;확진자수 하향성 횡보…특별방역주간 종료&quot; 99 : 여수시, 거리두기 2단계 16일까지 연장 100 : '한강 실종 대학생' 꼬리 무는 루머들…친구 조사는 언제쯤

# %%
import requests
from bs4 import BeautifulSoup
import re

for i in range(1, 1000, 10):
    url = "https://search.naver.com/search.naver?where=kin&kin_display=10&qt=&title=0&&answer=0&grade=0&choice=0&sec=0&nso=so%3Ar%2Ca%3Aall%2Cp%3Aall&query=%EC%A7%84%EB%A3%8C&c_id=&c_name=&sm=tab_pge&kin_start=",i,"&kin_age=0"
    req = requests.get('https://search.naver.com/search.naver?where=kin&kin_display=10&qt=&title=0&&answer=0&grade=0&choice=0&sec=0&nso=so%3Ar%2Ca%3Aall%2Cp%3Aall&query=%EC%A7%84%EB%A3%8C&c_id=&c_name=&sm=tab_pge&kin_start=1&kin_age=0')
    html = req.text
    soup = BeautifulSoup(html, 'html.parser')
    titles = soup.select('#main_pack > section > div > ul > li > div > div.question_area > div > a')
    #points = soup.select('td.title > div > em')
    reviews = soup.select('#main_pack > section > div > ul > li > div > div.answer_area > div.answer_group > a')
    title = []
    review = [] 

    for dom in titles:
        content=re.sub("[^가-힣\s]", '', dom.text) 
        title.append(dom.text)

    for dom in reviews:
        #content=re.sub("신고", '', content)
        content=re.sub("[^가-힣\s]", '', dom.text)    
        review.append(content)
    commentLength = len(movie_title)   
    for i in range(commentLength):
        print("제목 : " + title[i])
        print("리뷰글 : " + review[i])
        print("-----------------------------------------")

# %%
import urllib.request
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys 
import time
import re

url = "https://search.naver.com/search.naver?where=kin&sm=tab_jum&query=%EC%A7%84%EB%A3%8C"

driver = webdriver.Chrome('C:/Temp/chromedriver')
driver.implicitly_wait(5) 

driver.get(url)

# %%
works = []
while True:
    titles = driver.find_elements_by_css_selector("#main_pack > section > div > ul > li > div > div.question_area > div > a")

    reviews = driver.find_elements_by_css_selector("#main_pack > section > div > ul > li > div > div.answer_area > div.answer_group > a")

    for title in titles:
        #print(title.text,sep='')
        works.append(title.text)
    for review in reviews:
        #print(review.text,sep='', end=' ')
        works.append(title.text)
        
    nextbtn = driver.find_element_by_css_selector("#main_pack > div.api_sc_page_wrap > div > a.btn_next")
    if nextbtn.get_attribute('aria-disabled') == "true":
        print("work finished")
        break
    else:
        driver.execute_script("arguments[0].click();", nextbtn)
        time.sleep(1)
    
wfile = open("output/collect.txt","at", encoding="utf-8") 
wfile.writelines(works) 
wfile.close()
# Out:
# work finished
